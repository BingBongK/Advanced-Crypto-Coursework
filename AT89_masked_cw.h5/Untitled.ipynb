# %%
import h5py

file = h5py.File("AT89_masked_cw.h5", "r")
print(list(file.keys()))
# Out:
# ['inputs', 'traces']

# %%
inputs = file['inputs'][:]
traces = file['traces'][:]

print(inputs.shape)
print(traces.shape)
# Out:
# (2500, 16)
# (2500, 2210)
